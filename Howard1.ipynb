# %% [markdown]
# # Ronan Howard

# %% [markdown]
# ## Phases of Analysis and Visualization

# %% [markdown]
# 1. Get the Data
# 2. Clean the Data
# 3. Prepare the Data
# 4. Analyze the Data
# 5. Visualize the Data

# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 7434  Alabama 2016-07-29 2016-08-18                    Ipsos    A-  ...
# 7628  Alabama 2016-08-10 2016-08-16  Google Consumer Surveys     B  ...
# 6238  Alabama 2016-10-10 2016-10-14  Google Consumer Surveys     B  ...
# 7142  Alabama 2016-09-07 2016-09-13  Google Consumer Surveys     B  ...
# 6225  Alabama 2016-10-18 2016-10-26             SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
# 6225         34.53319      53.30648         4.332718               NaN
#
#       multiversions                                                url  \
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6225            NaN  https://www.surveymonkey.com/elections/map?pol...
#
#       poll_id  question_id  createddate             timestamp
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
# 6225    47556        74446     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %%
polls.sort_values('state', inplace=True)
polls.head(2)
# Out:
# C:\Users\rchow\AppData\Local\Temp\ipykernel_15300\1028685049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls.sort_values('state', inplace=True)
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5997   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate      pollster grade  ...  adjpoll_clinton  \
# 7434  Alabama 2016-07-29 2016-08-18         Ipsos    A-  ...         36.01944
# 5997  Alabama 2016-10-27 2016-11-02  SurveyMonkey    C-  ...         33.63222
#
#      adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  multiversions  \
# 7434      56.00800              NaN               NaN            NaN
# 5997      52.90133         2.269698               NaN            NaN
#
#                                                     url  poll_id  question_id  \
# 7434           http://www.reuters.com/statesofthenation    44940        68973
# 5997  https://www.surveymonkey.com/elections/map?pol...    48129        75398
#
#       createddate             timestamp
# 7434      8/24/16  09:24:53  8 Nov 2016
# 5997      11/3/16  09:24:53  8 Nov 2016
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
polls.sort_values('state', ascending=False).head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 5595   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5465   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7002   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6508   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 4616   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 5595  Wyoming 2016-10-24 2016-10-30             SurveyMonkey    C-  ...
# 5465  Wyoming 2016-10-29 2016-11-04             SurveyMonkey    C-  ...
# 7002  Wyoming 2016-08-24 2016-08-30  Google Consumer Surveys     B  ...
# 6508  Wyoming 2016-09-21 2016-09-26  Google Consumer Surveys     B  ...
# 4616  Wyoming 2016-11-01 2016-11-07             SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 5595         21.66060      62.70650         4.911339               NaN
# 5465         20.67782      59.66473         5.503678               NaN
# 7002         29.16335      52.06328         5.185009               NaN
# 6508         25.16699      54.53099         8.103150               NaN
# 4616         19.55778      59.36816         6.682125               NaN
#
#       multiversions                                                url  \
# 5595            NaN  https://www.surveymonkey.com/elections/map?pol...
# 5465            NaN  https://www.surveymonkey.com/elections/map?pol...
# 7002            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6508            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 4616            NaN  https://www.surveymonkey.com/elections/map?pol...
#
#       poll_id  question_id  createddate             timestamp
# 5595    47844        74867     10/31/16  09:24:53  8 Nov 2016
# 5465    48464        75934      11/5/16  09:24:53  8 Nov 2016
# 7002    45540        70925       9/9/16  09:24:53  8 Nov 2016
# 6508    46284        72343      9/28/16  09:24:53  8 Nov 2016
# 4616    48910        76600      11/8/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 7434  Alabama   7/29/2016   8/18/2016                    Ipsos    A-  ...
# 7628  Alabama   8/10/2016   8/16/2016  Google Consumer Surveys     B  ...
# 6238  Alabama  10/10/2016  10/14/2016  Google Consumer Surveys     B  ...
# 7142  Alabama    9/7/2016   9/13/2016  Google Consumer Surveys     B  ...
# 6225  Alabama  10/18/2016  10/26/2016             SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
# 6225         34.53319      53.30648         4.332718               NaN
#
#       multiversions                                                url  \
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6225            NaN  https://www.surveymonkey.com/elections/map?pol...
#
#       poll_id  question_id  createddate             timestamp
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
# 6225    47556        74446     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Rename voting columns

# %%
polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                      'rawpoll_trump':'Trump_pct'},inplace=True)
polls.head()
# Out:
# C:\Users\rchow\AppData\Local\Temp\ipykernel_15300\4063675258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 7434  Alabama   7/29/2016   8/18/2016                    Ipsos    A-  ...
# 7628  Alabama   8/10/2016   8/16/2016  Google Consumer Surveys     B  ...
# 6238  Alabama  10/10/2016  10/14/2016  Google Consumer Surveys     B  ...
# 7142  Alabama    9/7/2016   9/13/2016  Google Consumer Surveys     B  ...
# 6225  Alabama  10/18/2016  10/26/2016             SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
# 6225         34.53319      53.30648         4.332718               NaN
#
#       multiversions                                                url  \
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6225            NaN  https://www.surveymonkey.com/elections/map?pol...
#
#       poll_id  question_id  createddate             timestamp
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
# 6225    47556        74446     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]
polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
polls.head()
# Out:
# C:\Users\rchow\AppData\Local\Temp\ipykernel_15300\732497925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 7434  Alabama 2016-07-29 2016-08-18                    Ipsos    A-  ...
# 7628  Alabama 2016-08-10 2016-08-16  Google Consumer Surveys     B  ...
# 6238  Alabama 2016-10-10 2016-10-14  Google Consumer Surveys     B  ...
# 7142  Alabama 2016-09-07 2016-09-13  Google Consumer Surveys     B  ...
# 6225  Alabama 2016-10-18 2016-10-26             SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
# 6225         34.53319      53.30648         4.332718               NaN
#
#       multiversions                                                url  \
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6225            NaN  https://www.surveymonkey.com/elections/map?pol...
#
#       poll_id  question_id  createddate             timestamp
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
# 6225    47556        74446     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Try two plots

# %%
polls.plot.line(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# <Axes: xlabel='enddate'>

# %%
# %%time
polls.query('state == "U.S."') \
    .plot(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# CPU times: total: 46.9 ms
# Wall time: 46 ms
# <Axes: xlabel='enddate'>

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# date_cols   list         n=2
# pd          module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# poll_url    str          http://projects.fivethirt<...>nt_general_polls_2016.csv
# polls       DataFrame          cycle     branch   <...>n[4208 rows x 27 columns]

# %%
print(type(polls))
# Out:
# <class 'pandas.core.frame.DataFrame'>
